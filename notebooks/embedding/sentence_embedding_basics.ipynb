# %% [markdown]
# # Sentence embedding: Embedding more than words with sentence transformers

# %% [markdown]
# This notebook shows how to use [**sentence transformers**](https://sbert.net/) to generate **_contextualized_ embeddings for longer text sequences** like sentences or short paragraphs.
#
# <br><a target="_blank" href="https://colab.research.google.com/github/haukelicht/advanced_text_analysis/blob/main/notebooks/embedding/sentence_embedding_basics.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Note:** If running on Google Colab, make sure to use a GPU runtime (go to Runtime > Change runtime type, select "T4 GPU", and click save). See [this guide](https://github.com/haukelicht/advanced_text_analysis/blob/main/setup/setup_colab_runtime.md).
#
# ### Setup

# %%
# check if on colab
COLAB=True
try:
    import google.colab
except:
    COLAB=False

if COLAB:
    # shallow clone of current state of main branch 
    # !git clone --branch main --single-branch --depth 1 --filter=blob:none https://github.com/haukelicht/advanced_text_analysis.git
    # install required packages
    # %pip install -q sentence-transformers~=6.1.0 seaborn~=0.13.2 umap-learn~=0.5.12

# %%
# for data wrangling
from pathlib import Path
import pandas as pd
import numpy as np

# for embedding and similarity calculation
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import cos_sim

# for dimensionality reduction
from umap import UMAP 

# for visaualization
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML
print_html = lambda x: display(HTML(x.to_html(index=False)))

# %%
data_path = "data/labeled/sylvester_parlee_2022"
data_path = ("/content/advanced_text_analysis/" if COLAB else "../../") + data_path
data_path = Path(data_path)
data_file = "sylvester_parlee_2022-uk_cap_sentences.csv"

# %%
SEED = 42

# %%
MODEL_ID = "sentence-transformers/all-MiniLM-L6-v2"

# %% [markdown]
# ## Load example data
#
# Here we use a corpus of sentences from speeches delivered in the UK *House of Commons* that have been human-coded according to the Comparative Agendas Project (CAP) policy topic coding scheme.

# %%
fp = data_path / data_file

# %%
if not fp.exists():
    url = "https://cta-text-datasets.s3.eu-central-1.amazonaws.com/labeled/sylvester_parlee_2022/sylvester_parlee_2022-uk_cap_annotations.csv"
    df = pd.read_csv(url)
    fp.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(fp, index=False)

# %%
# read the data
df = pd.read_csv(fp)

# %% [markdown]
# Let's see how long theses sentences tend to be:

# %%
(df.text.str.strip().str.split('\s+', regex=True).apply(len)+1).describe().astype(int)
# Out:
# count    3948
# mean       26
# std        15
# min         2
# 25%        16
# 50%        24
# 75%        34
# max       375
# Name: text, dtype: int64

# %% [markdown]
# ## Sentence embedding
#
# ### Load the model

# %%
# instantiate a sentence embedding model (source: https://www.sbert.net/docs/pretrained_models.html)
embedding_model = SentenceTransformer(MODEL_ID)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %% [markdown]
# **_Note:_** Check the leaderboard for sentence embedding: https://huggingface.co/spaces/mteb/leaderboard ([*source*](https://maartengr.github.io/BERTopic/getting_started/embeddings/embeddings.html#sentence-transformers)). There you might find a model that achieves better performance or can ingest longer texts, like 'dunzhang/stella_en_400M_v5' or 'Alibaba-NLP/gte-large-en-v1.5'
#
# ### Preparing the text data
#
# ::: {.callout-warning title="Important"}
#
# It's important to remember that *every* transformer has a maximum number of tokens it can ingest per input document.
# As the name implies, sentence embedding models works best for either sentences or paragraphs. If your texts are longer documents, they will be truncated which might results in systematic information loss.
#
# So you should **always check** if the documents you want to embed are too long for the model you want to use.
#
# :::

# %%
# get the embedding model's max sequence length (measured in tokens)
embedding_model.max_seq_length
# Out:
# 256

# %%
# tokenize your texts with the pre-trained model and get the length of each tokenized text
toks = embedding_model.tokenizer(df.text.tolist(), return_length=True, truncation=False)
df['n_toks'] = toks.length
# Out:
# [transformers] Token indices sequence length is longer than the specified maximum sequence length for this model (430 > 256). Running this sequence through the model will result in indexing errors

# %% [markdown]
# ::: {.callout-note}
#
# `return_length=True` means that the returned object (`toks`) will include the length of each tokenized text.
#
# `truncation=False` means that the texts will not be truncated to the model's maximum input length.
#
# :::

# %%
# NOTE: don't just do white space splitting – it will underestimate the sequence length ;)
df['n_words'] = df.text.str.split(' ').apply(len)

# %% [markdown]
# ::: {.callout-warning title="More tokens than words"}
#
# Note that sentences have **more tokens than words**.
#
# This is because
#
# - words may be split into multiple subword tokens, especially for rare or complex words.
# - special tokens aree added to the tokenized text, such as `[CLS]` and `[SEP]` for BERT-based models.
#
# :::

# %%
df['n_toks'].hist(color = "green", alpha=0.5, bins=30)
df['n_words'].hist(color = "blue", alpha=0.5, bins=30)
plt.legend(['# tokens', '# words'])
plt.show()

# %%
# compute share of sentences that will be truncated
(df['n_toks'] > embedding_model.max_seq_length).mean()
# Out:
# np.float64(0.00025329280648429586)

# %%
# which texts are too long?
df[df['n_toks'] > embedding_model.max_seq_length]
# Out:
#       text_id                                               text  \
# 2081   133587  I beg to move, That this House: Deplores the u...
#
#             speaker party        date                                 agenda  \
# 2081  David Cameron   Con  29/08/2013  Syria and the Use of Chemical Weapons
#
#       cap_topic  n_toks  n_words
# 2081         16     430      374

# %% [markdown]
# In this corpus, only one text is too long.
# This should be fine.
# But note that too long texts' content will be truncated by the model's tokenizer on the right side (i.e., part of the end of the text will be discarded).
#
# ::: {.callout-warning title="Many too long documents?"}
#
# If many of your documents are too long, read [this thread](https://www.reddit.com/r/LanguageTechnology/comments/xh71yt/comment/j4fbqti/).
# They suggest to use a Transformer model with a higher max. sequence length (e.g., a "Longformer").
#
# <!-- This you could use to create document embeddings with the huggingface `pipeline` API (see [here](https://maartengr.github.io/BERTopic/getting_started/embeddings/embeddings.html#hugging-face-transformers)).  -->
#
# <!-- Alternatively, you can consider an [alternative document representation](https://maartengr.github.io/BERTopic/getting_started/embeddings/embeddings.html) approach. -->
#
# :::
#
# ### Embed the texts

# %%
# WARNING: this will take some time if you use a CPU
embeddings = embedding_model.encode(
    df.text.tolist(),           # this list of texts to embed
    batch_size=16,              # how many texts to process in parallel per step
    normalize_embeddings=True,  # make all embeddings have length = 1, so distances are cosine distances
    show_progress_bar=True      # display a progress bar when iterating over text batches
)
# Out:
# Batches:   0%|          | 0/247 [00:00<?, ?it/s]

# %% [markdown]
# ::: {.callout-note title="Embedding the texts"}
#
# We embed the texts using the model we loaded earlier.
#
# The **`model.encode()`** method will be used to convert the texts into embeddings. It expects **a list of strings as input**, where each string represents a single text document.
#
# We also pass additional parameters to control the behavior of the encoding process, such as `batch_size` and `show_progress_bar`. You can ignore them if you are fine with the default settings.
#
# :::
#
# ## Computing similarity
#
# Let's sample a couple of sentences labeled with topic "Development, Planning and Housing Issues" (ID: 14) and compare their pairwise similarities.

# %%
# subset 
expls = df[df.cap_topic==14]["text"].sample(n=50, random_state=42)

expl_embeddings = embeddings[expls.index]

# %%
similarities = cos_sim(expl_embeddings, expl_embeddings)

# convert to numpy array
similarities = similarities.numpy()

# show
print(similarities[1:5, 1:5].round(3))
# Out:
# [[1.    0.244 0.193 0.387]
#  [0.244 1.    0.12  0.161]
#  [0.193 0.12  1.    0.219]
#  [0.387 0.161 0.219 1.   ]]

# %%
# mask the diagonal
np.fill_diagonal(similarities, np.nan)
# set the lower triangle to 0 as well
similarities[np.tril_indices_from(similarities, k=-1)] = np.nan

print(similarities[1:5, 1:5].round(3))
# Out:
# [[  nan 0.244 0.193 0.387]
#  [  nan   nan 0.12  0.161]
#  [  nan   nan   nan 0.219]
#  [  nan   nan   nan   nan]]

# %%
# get the pairwise similarities for the sampled examples
sims_df = pd.DataFrame(similarities, index=expls, columns=expls)
sims_df.reset_index(names="text1", inplace=True)
sims_df = sims_df.melt(id_vars="text1", var_name="text2", value_name="similarity")
sims_df = sims_df[sims_df["similarity"].notna()]
sims_df.sort_values(by="similarity", ascending=False, inplace=True)

# %%
# show top 5 most similar pairs
print_html(sims_df.head(5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text1</th>
#       <th>text2</th>
#       <th>similarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Secondly-and forgive me for mentioning this, Madam Deputy Speaker-why should such a measure apply in London when there is no such provision in the rest of the UK?</td>
#       <td>That policy will apply not just in London, and the Deputy Prime Minister should be upset because the problem will also occur in Sheffield.</td>
#       <td>0.639714</td>
#     </tr>
#     <tr>
#       <td>I refer to the crucial issue of mixed housing developments.</td>
#       <td>Until enough houses are built to meet the needs of communities, any measures to assist in making housing more affordable are likely simply to tinker around the edges of the problem.</td>
#       <td>0.605616</td>
#     </tr>
#     <tr>
# ...

# %%
print_html(sims_df.tail(5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text1</th>
#       <th>text2</th>
#       <th>similarity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>It runs along the busy A24 trunk road into London and stands directly above the Northern line.</td>
#       <td>It was rarely the case that initiatives were judged by the Committee to be an unqualified success.</td>
#       <td>-0.071312</td>
#     </tr>
#     <tr>
#       <td>It runs along the busy A24 trunk road into London and stands directly above the Northern line.</td>
#       <td>Friend that we have made 3,000 payments to policyholders just today.</td>
#       <td>-0.076088</td>
#     </tr>
#     <tr>
#       <td>I may be considered an old romantic, but I believe that the beating heart of the west midlands is our manufacturing industry.</td>
# ...

# %% [markdown]
# ## Dimensionality reduction
#
# Let's try to locate the texts and cluster them based on their embeddings.
# This should give us a _roughly_ **topical clustering**.
#
# Let's use the topic of the debate from which the speech sentence comes as a "soft" label
# to see how well the embedding model capture topical information.

# %%
df['cap_topic'].unique()
# Out:
# array([16, 10,  3, 99, 12, 19, 20, 14,  1,  6,  5, 13, 21,  2,  8,  4,  7,
#        15, 17, 18])

# %% [markdown]
# | code | topic |
# | --:|:------- |
# |  1 | Macroeconomics |
# |  2 | Civil Rights, Minority Issues, Immigration and Civil Liberties |
# |  3 | Health |
# |  4 | Agriculture |
# |  5 | Labour and Employment |
# |  6 | Education and Culture |
# |  7 | Environment |
# |  8 | Energy |
# |  9 | Immigration |
# | 10 | Transportation |
# | 12 | Law, Crime and Family Issues |
# | 13 | Social Welfare |
# | 14 | Community Development, Planning and Housing Issues |
# | 15 | Banking, Finance and Domestic Commerce |
# | 16 | Defence |
# | 17 | Space, Science, Technology and Communications |
# | 18 | Foreign Trade |
# | 19 | International Affairs and Foreign Aid |
# | 20 | Government Operations |
# | 21 | Public Lands, Water Management, Colonial and Territorial Issues |
# | 99 | Non-policy content |
#
# let's focus on COVID-19 related debates

# %%
topics_map = {
    1: "Macroeconomics",
    3: "Health",
    6: "Education and Culture",
    # 7: "Environment",
    9: "Immigration",
    14: "Community Development, Planning and Housing Issues",
}

# %%
# subset the data to only include speeches from the selected topics
tmp = df[df.cap_topic.isin(topics_map.keys())]

# subsample at least 200 examples for each topic
tmp = tmp.groupby('cap_topic').apply(
    lambda x: x.sample(n=min(200, len(x)), random_state=42)
).reset_index(level=0, names=['cap_topic'])

# apply topic label

tmp['cap_topic_label'] = tmp['cap_topic'].map(topics_map)

# %% [markdown]
# ::: {.callout-warning title="high-D"}
#
# The embeddings are high-dimensional.
#
# ✅ This is valuable for similarity computation
#
# ❌ This can make visualization and interpretation challenging.
#
# :::
#
# We use the [UMAP algortihm](https://umap-learn.readthedocs.io/en/latest/how_umap_works.html) to reduce the high-dimensional embeddings to a 2D space for visualization and interpretation:

# %%
umap_model = UMAP(
    n_neighbors=50, 
    n_components=2, # use only 2D for visualization
    min_dist=0.0,
    metric='cosine', 
    random_state=SEED,
    n_jobs=1
)

# %%
# Apply the UMAP model to the embeddings of the sentences in the subsetted data
embeddings_2d = umap_model.fit_transform(embeddings[tmp.index])

# %%
# Create a scatter plot of the 2D embeddings, colored by debate_subject
plt.figure(figsize=(6, 4))
sns.scatterplot(x=embeddings_2d[:, 0], y=embeddings_2d[:, 1], hue=tmp['cap_topic_label'], s=10, alpha=0.8, legend='full')
plt.xlabel('UMAP dimension 1')
plt.ylabel('UMAP dimension 2')
plt.rcParams.update({"legend.fontsize": 8})
plt.legend(bbox_to_anchor=(0.5, 1.15), loc='upper center', ncol=2, frameon=False)
plt.show()

# %% [markdown]
# ::: {.callout-tip title="Interpretation"}
#
# The scatter plot visualizes the 2D embeddings of the sentences, with points colored according to the human-coded policy topic of the sentences.
#
# It shows that sentences into the same category tend to cluster together in the 2D projection of the embedding space, indicating that the sentence embedding model already captures thematic/topical similarities aligned with the human-coded policy topics -- _without_ havong been trained for the particular classification task!
#
# Stray points that are far beyond their topic clusters' dense region appear for two reasons in the 2D projection:
#
# - either the sentence is genuinely an outlier in its topic, or
# - the dimensionality reduction has distorted its position relative to the cluster
#
# :::
