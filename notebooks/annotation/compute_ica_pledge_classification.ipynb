# %% [markdown]
# # Computing inter-annotator agreement for sentence classification tasks

# %% [markdown]
# <br><a target="_blank" href="https://colab.research.google.com/github/haukelicht/advanced_text_analysis/blob/main/notebooks/annotation/compute_ica_pledge_classification.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# We want to compute to what extent annotators' sentence-level classifications agree with each other.
# Specifically, following Krippendorff ([2022](https://doi.org/10.4135/9781071878781.n13)) and others (see Neuendorff, [2017](https://doi.org/10.4135/9781071802878.n6)), we want to compute a _chance-adjusted_ inter-annotator agreement metric that adjusts for the probability that an agreement arises by chance.

# %% [markdown]
# ### Setup

# %%
# check if on colab
COLAB = True
try:
    import google.colab
except:
    COLAB=False

if COLAB:
    # shallow clone of current state of main branch 
    # !git clone --branch main --single-branch --depth 1 --filter=blob:none https://github.com/haukelicht/advanced_text_analysis.git
    # make repo root findable for python
    import sys
    sys.path.append("/content/advanced_content_analysis/")
    
    # install required packages
    # !pip install krippendorff==0.8.1

# %%
from pathlib import Path

import pandas as pd
from scipy.stats import entropy

from krippendorff import alpha as k_alpha

base_path = Path("/content/advanced_text_analysis/" if COLAB else "../../")
data_path = base_path / "data" / "labeled" / "fornaciari_we_2021"

# %% [markdown]
# ## Read the annotations

# %%
# TODO: change `"llms"` to the name of your group's folder
annotations_path = data_path / "annotations" / "classification" / "group3"

# list all annotation files produced by doccano 
#  (each records annotations by one annotator)
fps = list(annotations_path.glob('*.csv'))

# read the annoations into a long-format DataFrame
annotations = pd.concat({fp.stem: pd.read_csv(fp) for fp in fps}, ignore_index=False).reset_index(level=0, names=['annotator'])

# list unique annotators
annotations.annotator.unique().tolist()
# Out:
# ['luisa.kutlar', 'johanneskuhling', 'lopatina']

# %%
annotations[annotations.annotator=='luisa.kutlar']
# Out:
#        annotator      id                                               text  \
# 0   luisa.kutlar  133935  10 . Protecting Indians overseas from exploita...
# 1   luisa.kutlar  133936  An ‘Extremely Backward Communities Development...
# 2   luisa.kutlar  133937  Similarly, almost all remaining households hav...
# 3   luisa.kutlar  133938  We will expand this initiative further to take...
# 4   luisa.kutlar  133939  In this sacred endeavour, the Congress has joi...
# 5   luisa.kutlar  133940  The Indian National Congress has always stood ...
# 6   luisa.kutlar  133941  We are committed to annulling Article 35A of t...
# 7   luisa.kutlar  133942  A suitable law, enabling micro - credit operat...
# 8   luisa.kutlar  133943  Education at all stages — primary, secondary a...
# 9   luisa.kutlar  133944  The Indian National Congress is committed to p...
# 10  luisa.kutlar  133945  The party believes in the principle of unity i...
# 11  luisa.kutlar  133946  We will increase the strength of the diplomati...
# 12  luisa.kutlar  133947  provide tax incentives for investments in rese...
# 13  luisa.kutlar  133948  Most of the plans had been finalized before th...
# 14  luisa.kutlar  133949  The manifesto is an opportunity for a politica...
# 15  luisa.kutlar  133950  It has launched the National Rural Health Miss...
# 16  luisa.kutlar  133951  There shall be a special survey, which will be...
# 17  luisa.kutlar  133952  Launch a National Digital Highway Development ...
# 18  luisa.kutlar  133953  Dispense with clubbing of agricultural income ...
# 19  luisa.kutlar  133954  PHCs will provide all primary health services,...
# 20  luisa.kutlar  133955  The recently established National Security Cou...
# 21  luisa.kutlar  133956  Congress will work with State Governments to e...
# 22  luisa.kutlar  133957  It is, as has become painfully evident, not co...
# 23  luisa.kutlar  133958  9 . We will set up a “National Panchayati Raj ...
# 24  luisa.kutlar  133959  The BJP will set up an experts committee to de...
# 25  luisa.kutlar  133960  We aspire to be the world's third largest econ...
# 26  luisa.kutlar  133961  Deployment of broadband in every village would...
# 27  luisa.kutlar  133962  The Credit Guarantee Scheme of the Government ...
# 28  luisa.kutlar  133963  We will offer higher interest rates on fixed d...
# 29  luisa.kutlar  133964  Working of regulatory bodies, which oversee me...
# 30  luisa.kutlar  133965  MGNREGA will also be harnessed to support the ...
# 31  luisa.kutlar  133966  We reach out to the minorities and even at the...
# 32  luisa.kutlar  133967  3 . Announce a detailed Jobs Agenda to ensure ...
# 33  luisa.kutlar  133968  India will engage with the world in the global...
# 34  luisa.kutlar  133969  Saving Rama Setu is to save the vast thorium d...
# 35  luisa.kutlar  133970  We propose to take strong measures to promote ...
# 36  luisa.kutlar  133971  The Congress will ensure the fullest implement...
# 37  luisa.kutlar  133972  The Indian National Congress will bring school...
# 38  luisa.kutlar  133973  The present system of setting Minimum Support ...
# 39  luisa.kutlar  133974  A ‘Vishwakarma Initiative’ will be launched fo...
# 40  luisa.kutlar  133975  We want an India which we all feel part of, in...
# 41  luisa.kutlar  133976  But at the same time, governance in these stat...
# 42  luisa.kutlar  133977  The NDA Government envisions a future that res...
# 43  luisa.kutlar  133978  Continuing our work, we will legislate a bill ...
# 44  luisa.kutlar  133979  Flawed design, inefficient execution, insuffic...
# 45  luisa.kutlar  133980  The sustained campaign led by the Congress Pre...
# 46  luisa.kutlar  133981  Along the lines of NREGA, we will enact a Nati...
# 47  luisa.kutlar  133982  21 Ensure the LPG gas cylinder connection to a...
# 48  luisa.kutlar  133983  a . We will enact central legislation on the S...
# 49  luisa.kutlar  133984  Launch a massive programme to detect, detain a...
#
#     split_  text_id  metadata__year metadata__party      label
# 0        2      773            2014             INC  No Pledge
# 1        2      534            2009             BJP     Pledge
# 2        2      313            2019             BJP  No Pledge
# 3        2      444            2019             BJP     Pledge
# 4        2       19            2004             INC  No Pledge
# 5        2      249            2009             INC     Pledge
# 6        2      101            2019             BJP     Pledge
# 7        2      518            2004             BJP     Pledge
# 8        2      253            2009             INC     Pledge
# 9        2      630            2014             INC     Pledge
# 10       2      147            2014             BJP  No Pledge
# 11       2      642            2019             BJP  No Pledge
# 12       2      616            2014             BJP     Pledge
# 13       2      117            2004             INC  No Pledge
# 14       2      963            1999             INC  No Pledge
# 15       2      117            2009             INC  No Pledge
# 16       2      343            2014             INC     Pledge
# 17       2      450            2009             BJP     Pledge
# 18       2      256            2009             BJP  No Pledge
# 19       2      863            2019             INC     Pledge
# 20       2      150            1999             BJP  No Pledge
# 21       2      948            2019             INC  No Pledge
# 22       2       69            2009             INC  No Pledge
# 23       2      481            2014             INC     Pledge
# 24       2      354            2009             BJP     Pledge
# 25       2       18            2019             BJP     Pledge
# 26       2      197            2014             BJP  No Pledge
# 27       2      210            2019             BJP  No Pledge
# 28       2      572            2019             BJP     Pledge
# 29       2      700            2004             BJP  No Pledge
# 30       2      503            2014             INC  No Pledge
# 31       2       36            1999             BJP     Pledge
# 32       2      241            2014             INC  No Pledge
# 33       2      107            2009             BJP  No Pledge
# 34       2      738            2009             BJP  No Pledge
# 35       2      523            2014             INC  No Pledge
# 36       2      216            2004             INC     Pledge
# 37       2      288            2009             INC     Pledge
# 38       2      140            2004             BJP  No Pledge
# 39       2      404            2004             BJP     Pledge
# 40       2       44            1999             BJP  No Pledge
# 41       2      775            1999             INC  No Pledge
# 42       2      890            2004             BJP  No Pledge
# 43       2      514            2019             BJP     Pledge
# 44       2      146            2019             INC  No Pledge
# 45       2      140            2009             INC  No Pledge
# 46       2      200            2009             INC     Pledge
# 47       2      675            2019             BJP     Pledge
# 48       2      164            2014             INC     Pledge
# 49       2       88            2009             BJP     Pledge

# %%
annotations.value_counts(['annotator', 'label']).unstack(fill_value=0)
# Out:
# label            No Pledge  Pledge
# annotator
# johanneskuhling         24      26
# lopatina                28      22
# luisa.kutlar            26      24

# %% [markdown]
# ## Compute inter-annotator agreement

# %%
tmp = annotations[['annotator', 'text_id', 'label']].copy()
tmp['label'] = (tmp['label'].str.lower()=='pledge').astype(int)
tmp = tmp.pivot_table(index='annotator', columns='text_id', values='label').fillna(0).astype(int)
k_alpha(tmp.values, level_of_measurement='nominal')
# Out:
# 0.6413966049382716

# %% [markdown]
# Krippendorff (cited in Neuendorff, 2017) names the following standards
#
# - Rely only on variables with reliabilities above α = .800.
# - Consider variables with reliabilities between α = .667 and α = .800 only for drawing tentative conclusions.

# %% [markdown]
# ## Sentence-level disagreement analysis

# %%
def compute_entropy(x: pd.Series) -> float:
    """Compute entropy of a value counts series."""
    return entropy(x.value_counts(normalize=True).values, base=2)

n_annotators = 4
print("perfect agreement")
print(f" - on positive label: entropy = {compute_entropy(pd.Series(['Pledge']*n_annotators)):.03f}")
print(f" - on negative label: entropy = {compute_entropy(pd.Series(['No Pledge']*n_annotators)):.03f}")
print('some agreement:')
print(f" - on positive label: entropy = {compute_entropy(pd.Series(['Pledge']*(n_annotators-1) + ['No Pledge']*1)):.03f}")
print(f" - on negative label: entropy = {compute_entropy(pd.Series(['Pledge']*1 + ['No Pledge']*(n_annotators-1))):.03f}")
print(f"no agreement (tied):  entropy = {compute_entropy(pd.Series(['Pledge', 'No Pledge']*int(n_annotators/2))):.03f}")
# Out:
# perfect agreement
#  - on positive label: entropy = 0.000
#  - on negative label: entropy = 0.000
# some agreement:
#  - on positive label: entropy = 0.811
#  - on negative label: entropy = 0.811
# no agreement (tied):  entropy = 1.000

# %%
entropies = annotations.groupby('text_id').agg({'label': compute_entropy}).reset_index().rename(columns={'label': 'entropy'})

# %%
entropies.entropy.value_counts(dropna=False)
# Out:
# entropy
# 0.000000    35
# 0.918296    13
# Name: count, dtype: int64

# %% [markdown]
# - There is perfect agreement in 39 out of 50 cases.
# - There is some disagreement in 7 cases.
# - There is complete disagreement in 4 cases.

# %% [markdown]
# #### poor agreement instances

# %%
instances = entropies.query('entropy > 0 and entropy < 1').merge(annotations[['text_id', 'text']].drop_duplicates(), on='text_id').sort_values('text_id')
instances = instances.merge(annotations.groupby('text_id').agg({'label': list}).reset_index())
instances
# Out:
#     text_id   entropy                                               text  \
# 0        36  0.918296  We reach out to the minorities and even at the...
# 1       150  0.918296  The recently established National Security Cou...
# 2       164  0.918296  a . We will enact central legislation on the S...
# 3       197  0.918296  Deployment of broadband in every village would...
# 4       241  0.918296  3 . Announce a detailed Jobs Agenda to ensure ...
# 5       249  0.918296  The Indian National Congress has always stood ...
# 6       343  0.918296  There shall be a special survey, which will be...
# 7       354  0.918296  The BJP will set up an experts committee to de...
# 8       503  0.918296  MGNREGA will also be harnessed to support the ...
# 9       630  0.918296  The Indian National Congress is committed to p...
# 10      642  0.918296  We will increase the strength of the diplomati...
# 11      700  0.918296  Working of regulatory bodies, which oversee me...
# 12      948  0.918296  Congress will work with State Governments to e...
#
#                              label
# 0   [Pledge, No Pledge, No Pledge]
# 1   [No Pledge, No Pledge, Pledge]
# 2      [Pledge, No Pledge, Pledge]
# 3   [No Pledge, Pledge, No Pledge]
# 4      [No Pledge, Pledge, Pledge]
# 5   [Pledge, No Pledge, No Pledge]
# 6      [Pledge, Pledge, No Pledge]
# 7      [Pledge, Pledge, No Pledge]
# 8   [No Pledge, Pledge, No Pledge]
# 9      [Pledge, No Pledge, Pledge]
# 10  [No Pledge, Pledge, No Pledge]
# 11  [No Pledge, Pledge, No Pledge]
# 12  [No Pledge, Pledge, No Pledge]

# %% [markdown]
# #### bad agreement

# %%
instances = entropies.query('entropy == 1.0').merge(annotations[['text_id', 'text']].drop_duplicates(), on='text_id').sort_values('text_id')
instances = instances.merge(annotations.groupby('text_id').agg({'label': list}).reset_index())
instances
# Out:
# Empty DataFrame
# Columns: [text_id, entropy, text, label]
# Index: []
