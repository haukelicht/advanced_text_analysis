# %% [markdown]
# # Fine-tune multi-label classifier using `setfit`
#
# *author*: **Hauke Licht** (hauke.licht@uibk.ac.at)
#
# <br>
#
# In this notebook, we fine-tune a model for multilabel classification using few-shot sentence transformer fine-tunint ("SeTFiT") with replication data from
#
# > Erlich A, Dantas SG, Bagozzi BE, Berliner D, Palmer-Rub. Multi-Label Prediction for Political Text-as-Data. *Political Analysis*. 2022; 30(4):463-480. DOI: [10.1017/pan.2021.15](https://doi.org/10.1017/pan.2021.15)
#
#
# Read more about setfit:
#
# - Tunstall L, Reimers N, Seo Jo UE, Bates L, Korat D, Wasserblat M, Pereg O. Efficient Few-Shot Learning Without Prompts. 2022. arXiv:[https://arxiv.org/abs/2209.11055](2209.11055)
# - https://github.com/huggingface/setfit
# - https://huggingface.co/docs/setfit/en/index
# - https://huggingface.co/docs/setfit/en/how_to/multilabel

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/haukelicht/advanced_text_analysis/blob/main/notebooks/encoder_finetuning/finetune_sequence_classifier_multilabel_setfit.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Background
#
# **Multilabel classification** means assigning each text item into none, one, or more label classes.
#
# <center>
#
# ![](../.assets/task_types-multilabel_classification.svg)
#
# </center>
#
# defining characteristics:
#
# - document-level classification: assign whole documents (e.g., sentences) categories
# - _multi_-label classification: assign each document to _none, one, or more_ categories
#
# ### multi-label classification implementation
#
# #### supervised learning (finetuning)
#
# given
#
# - pre-defined set of label classes C
# - n training examples ($x_i$, $\mathbf{y}_i$) where
# 	- $x_i$ is example i's text (representation) and
# 	- $\mathbf{y}_i$ is example i's _list of_ "ground truth" labels
# - a (pre-trained) model that
# 	- intakes text representations ($x_i$)
# 	- outputs _vector of_ predicted probabilities $\mathbf{\hat{y}}_i$
# - loss function: label-class specific binary cross entropy
#
# #### prompting (in-context learning)
#
# two approaches
#
# - collect binary (yes/no) classifications for each label class
# - prompt model to choose any label classes that apply
#
# ### methods papers and research applications
#
# - Erhard L, Hanke S, Remer U, Falenska A, Heiberger RH. PopBERT. Detecting Populism and Its Host Ideologies in the German Bundestag. *Political Analysis*. 2025;33(1):1-17. doi:[10.1017/pan12](https://doi.org/10.1017/pan.2024.12)
# - Erlich A, Dantas SG, Bagozzi BE, Berliner D, Palmer-Rub. Multi-Label Prediction for Political Text-as-Data. *Political Analysis*. 2022; 30(4):463-480. doi:[10.1017/pan.2021.15](https://doi.org/10.1017/pan.2021.15)
# - Kroon AC, van der Meer T, Vliegenthart R. Assessing Performance of Dictionaries, Supervised Machine Learning, and Embeddings in Topic and Frame Classification. *Computational Communication Research*. 2022; 4(2): 528 - 570. doi:[10.5117/CCR2022.2.006.KROO](https://doi.org/10.5117/CCR2022.2.006.KROO)
# <!-- - Omar A, Mahmoud TM, Abd-El-Hafeez T, Mahfouz A. Multi-label Arabic text classification in Online Social Networks. *Information Systems*. 2021; 100. doi:[10.1016/j.is.2021.101785](https://doi.org/10.1016/j.is.2021.101785) -->

# %% [markdown]
# ## Setup

# %% [markdown]
# #### Colab (if using Colab)

# %%
# check if on Colab
COLAB = True
try:
  from google import colab
except:
  COLAB = False

if COLAB:
    # shallow clone of current state of main branch 
    # %rm -rf /content/advanced_text_analysis
    # !git clone --branch main --single-branch --depth 1 --filter=blob:none https://github.com/haukelicht/advanced_text_analysis.git

# %%
# # NOTE: need to downgrade sentence-transformers and setfit to compatible versions
# %pip install -q "sentence-transformers==5.1.0 setfit==1.1.3"

# %%
# set the PYTHONPATH so modules in `src/` can be found
from pathlib import Path
import sys

if COLAB:
    import sys
    sys.path.append("/content/advanced_text_analysis/")
else:
    base_path = Path('../..')
    sys.path.append(str(base_path.resolve()))

# %%
# %pip install setfit==1.2.0

# %% [markdown]
# #### Load required libraries

# %%
from pathlib import Path
import shutil

import numpy as np
import pandas as pd
from datasets import Dataset, DatasetDict

import torch
from transformers import set_seed
from src.setfit_utils import model_init as setfit_model_init
from src.setfit_utils import get_class_weights
from setfit import TrainingArguments, Trainer

# %%
from sklearn.metrics import hamming_loss, accuracy_score, f1_score, label_ranking_loss

def multilabel_metrics(y_pred, y_true):
    # Apply sigmoid and threshold
    probs = 1 / (1 + np.exp(-y_pred))  # Sigmoid
    pred_binary = (probs > 0.5).astype(int)

    return {
        "hamming_loss": hamming_loss(y_true, pred_binary),
        "subset_accuracy": accuracy_score(y_true, pred_binary),
        "f1_macro": f1_score(y_true, pred_binary, average="macro"),
        "f1_micro": f1_score(y_true, pred_binary, average="micro"),
        "ranking_loss": label_ranking_loss(y_true, probs),
    }

# %% [markdown]
# **Interpretation**
#
# - *Hamming Loss*
#   - Measures the fraction of labels that are incorrectly predicted (either a 0 instead of 1 or vice versa).
#   - Lower is better; `0.0` means perfect prediction.
#   - Formula: `(number of wrong labels) / (number of total labels)`
#   - Good for understanding average label-wise error rate.
#
# - *Subset Accuracy (Exact Match Ratio)*
#   - Fraction of examples where **all** labels are predicted correctly.
#   - Very strict; requires the entire label set to be correct per sample.
#   - Value ranges from `0.0` (no perfect predictions) to `1.0` (all perfect).
#   - Not very forgiving if you're slightly wrong on multi-hot labels.
#
# - *F1-Macro*
#   - Calculates F1 score **per label**, then takes the unweighted average.
#   - Treats all labels equally regardless of how often they appear.
#   - Sensitive to performance on rare labels.
#   - Useful when class imbalance is a concern and all labels are important.
#
# - *F1-Micro*
#   - Aggregates true positives, false positives, and false negatives across all labels before computing F1.
#   - Gives more weight to frequent labels.
#   - Better when the number of positive examples per label varies a lot.
#   - Often higher than macro F1 in imbalanced datasets.
#
# - *Ranking Loss*
#   - Measures how often a **relevant label** is ranked lower than an irrelevant one.
#   - Lower is better; `0.0` means perfect ranking.
#   - Requires access to the **raw prediction scores** (before thresholding).
#   - Useful in retrieval or recommendation scenarios where ranking quality matters.

# %%
# check which device is available
device = torch.device('cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu')
device
# Out:
# device(type='mps')

# %%
MODEL_NAME = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"

# %%
SEED = 42
set_seed(SEED)

# %%
base_path = Path("/content/advanced_text_analysis/" if COLAB else "../../")
data_path = base_path / "data/labeled/erlich_multilabel_2023"
data_file = "erlich_multilabel_2023-ati_reqeuests.tsv"

# %% [markdown]
# ## Load and prepare the data

# %%
fp = data_path / data_file
if not fp.exists():
    url = f"https://cta-text-datasets.s3.eu-central-1.amazonaws.com/labeled/{data_path.name}/{data_file}"
    df = pd.read_csv(url, sep="\t")
    fp.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(fp, sep="\t", index=False)

# %%
from src.utils.io import read_tabular

df = read_tabular(fp)

# %%
del df['text']
df.rename(columns={'text_en': 'text'}, inplace=True)

# %%
from src.finetuning import split_data

data_splits = split_data(df, dev_size=0.25, test_size=0.25, seed=SEED, return_dict=True)

# %% [markdown]
# *NOTE*: `setfit` is a few-shot learning framework, so it can work with very little data; so let's subsample

# %%
data_splits['train'] = data_splits['train'].sample(1_500, random_state=SEED)

# %%
datasets = DatasetDict({
    s: Dataset.from_pandas(df, preserve_index=False)
    for s, df in data_splits.items()
})

# %%
label_cols = datasets.column_names['train']
label_cols = [c for c in label_cols if c not in ['id', 'text']]

id2label = {i: l for i, l in enumerate(label_cols)}
label2id = {l: i for i, l in enumerate(label_cols)}

id2label
# Out:
# {0: 'activities',
#  1: 'budget',
#  2: 'evaluation',
#  3: 'external_contracts',
#  4: 'inst_struc',
#  5: 'regulatory'}

# %%
def format_labels(example):
    example['labels'] = [float(example[col]) for col in label_cols]
    return example

datasets = datasets.map(format_labels)
# Out:
# Map:   0%|          | 0/1500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1195 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1195 [00:00<?, ? examples/s]

# %%
keep_cols = ['text' 'labels']
rm_cols = [col for col in datasets['train'].column_names if col not in keep_cols]
datasets.remove_columns(rm_cols);

# %%
datasets.num_rows
# Out:
# {'train': 1500, 'dev': 1195, 'test': 1195}

# %% [markdown]
# ## Prepare the model fine-tuning

# %%
labs = np.array(datasets['train']['labels'])
class_weights = get_class_weights(labs, multitarget=True)
class_weights = class_weights.astype(float)
class_weights
# Out:
# array([0.06704206, 0.19244664, 0.14227078, 0.19330963, 0.11167888,
#        0.29325202])

# %%
def model_init():
    return setfit_model_init(
        model_name=MODEL_NAME,
        id2label=id2label,
        multitarget_strategy='one-vs-rest', # !!!
        class_weights=class_weights,
    )

# %%
from src.metrics import compute_sequence_classification_metrics_multilabel
def compute_metrics(y_pred, y_true):
    # return multilabel_metrics(y_pred.numpy(), 
    return compute_sequence_classification_metrics_multilabel(np.array(y_true), y_pred.numpy())

# %% [markdown]
# ### Define the training arguments

# %%
model_path = base_path / "models" / "erlich_multilabel_setfit"

# %%
out_dir = model_path
checkpoints_dir = out_dir / 'checkpoints'
logs_dir = out_dir / 'logs'

from sentence_transformers.losses import CosineSimilarityLoss
from transformers import EarlyStoppingCallback

training_args = TrainingArguments(
    
    num_epochs=(1, 10), # embedding finetuning and classification head training epochs, respectively
    max_steps=250,
    batch_size=(16, 8),
    max_length=512,
    end_to_end=True,
    
    loss=CosineSimilarityLoss,
    
    # when to evaluate
    eval_strategy='steps',
    eval_steps=50,
    eval_max_steps=50,
    # how to select "best" model
    # do_eval=bool('dev' in datasets),
    metric_for_best_model='embedding_loss',
    load_best_model_at_end=True,
    # when to save
    save_strategy='steps',
    save_steps=50,
    save_total_limit=2 if 'dev' in datasets else None, # don't save all model checkpoints
    # where to store results
    output_dir=checkpoints_dir,
    
    report_to='none',
    seed=SEED,
)

# build callbacks
callbacks = []
if 'dev' in datasets:
    callbacks.append(EarlyStoppingCallback(early_stopping_patience=3, early_stopping_threshold=0.03))

# %% [markdown]
# ### Create the trainer

# %%
trainer = Trainer(
    model_init=model_init,
    train_dataset=datasets['train'],
    eval_dataset=datasets['dev'],
    args=training_args,
    column_mapping={"text": "text", "labels": "label"},
    metric=compute_metrics,
    callbacks=callbacks,
)

# for deterministic results
trainer._args.seed = SEED
trainer.st_trainer.args.seed = SEED
trainer.st_trainer.args.data_seed = SEED
trainer.st_trainer.args.full_determinism = True

# adapt max length
trainer.model.model_body.tokenizer.model_max_length = training_args.max_length
trainer.model.model_body.max_seq_length = training_args.max_length
# Out:
# Applying column mapping to the training dataset
# Applying column mapping to the evaluation dataset
# README.md:   0%|          | 0.00/5.12k [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# /Users/hlicht/Dropbox/teaching/advanced_text_analysis/advanced_text_analysis_repo/src/setfit_utils.py:125: FutureWarning: The `get_sentence_embedding_dimension` method has been renamed to `get_embedding_dimension`.
#   in_features=body.get_sentence_embedding_dimension(),
# Map:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %% [markdown]
# ## Train

# %%
print('Training ...')
trainer.train()
# Out:
# ***** Running training *****
#   Num unique pairs = 4000
#   Batch size = 16
#   Num epochs = 1
# Training ...
# /Users/hlicht/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='4' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  4/250 00:19 < 39:02, 0.11 it/s, Epoch 0.01/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 2
#       1 print('Training ...')
# ----> 2 trainer.train()
#
# File ~/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/setfit/trainer.py:536, in Trainer.train(self, args, trial, **kwargs)
#     531 train_parameters = self.dataset_to_parameters(self.train_dataset)
#     532 full_parameters = (
#     533     train_parameters + self.dataset_to_parameters(self.eval_dataset) if self.eval_dataset else train_parameters
#     534 )
# --> 536 self.train_embeddings(*full_parameters, args=args)
#     537 self.train_classifier(*train_parameters, args=args)
#
# File ~/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/setfit/trainer.py:587, in Trainer.train_embeddings(self, x_train, y_train, x_eval, y_eval, args)
#     579 if loss in (
#     580     losses.BatchAllTripletLoss,
#     581     losses.BatchHardTripletLoss,
#    (...)    584     SupConLoss,
#     585 ):
#     586     self.st_trainer.args.batch_sampler = BatchSamplers.GROUP_BY_LABEL
# --> 587 self.st_trainer.train()
#
# File ~/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/transformers/trainer.py:1458, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1456 ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1457 with ctx:
# -> 1458     return inner_training_loop(
#    1459         args=args,
#    1460         resume_from_checkpoint=resume_from_checkpoint,
#    1461         trial=trial,
#    1462         ignore_keys_for_eval=ignore_keys_for_eval,
#    1463     )
#
# File ~/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/transformers/trainer.py:1540, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1538 for epoch in range(epochs_trained, num_train_epochs):
#    1539     self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1540     self._run_epoch(
#    1541         model=model,
#    1542         epoch=epoch,
#    1543         train_dataloader=train_dataloader,
#    1544         steps_in_epoch=steps_in_epoch,
#    1545         num_update_steps_per_epoch=num_update_steps_per_epoch,
#    1546         trial=trial,
#    1547         ignore_keys_for_eval=ignore_keys_for_eval,
#    1548         start_time=start_time,
#    1549         resume_from_checkpoint=resume_from_checkpoint,
#    1550         epochs_trained=epochs_trained,
#    1551         steps_trained_in_current_epoch=steps_trained_in_current_epoch,
#    1552     )
#    1553     if self.control.should_training_stop:
#    1554         break
#
# File ~/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/transformers/trainer.py:1768, in Trainer._run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1766     sync_context = functools.partial(self.accelerator.no_sync, model=model)
#    1767 with sync_context():
# -> 1768     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    1770 if (
#    1771     self.args.logging_nan_inf_filter
#    1772     and not is_torch_xla_available()
#    1773     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1774 ):
#    1775     # if loss is nan or inf simply add the average of previous logged losses
#    1776     self._tr_loss += self._tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/transformers/trainer.py:1970, in Trainer.training_step(***failed resolving arguments***)
#    1967 if self.accelerator.distributed_type == DistributedType.DEEPSPEED:
#    1968     kwargs["scale_wrt_gas"] = False
# -> 1970 self.accelerator.backward(loss, **kwargs)
#    1972 return loss.detach()
#
# File ~/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/accelerate/accelerator.py:2850, in Accelerator.backward(self, loss, **kwargs)
#    2848     self.lomo_backward(loss, learning_rate)
#    2849 else:
# -> 2850     loss.backward(**kwargs)
#
# File ~/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/torch/_tensor.py:631, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     621 if has_torch_function_unary(self):
#     622     return handle_torch_function(
#     623         Tensor.backward,
#     624         (self,),
#    (...)    629         inputs=inputs,
#     630     )
# --> 631 torch.autograd.backward(
#     632     self, gradient, retain_graph, create_graph, inputs=inputs
#     633 )
#
# File ~/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/torch/autograd/__init__.py:379, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     374     retain_graph = create_graph
#     376 # The reason we repeat the same comment below is that
#     377 # some Python versions print out the first line of a multi-line function
#     378 # calls in the traceback and some print out the last line
# --> 379 _engine_run_backward(
#     380     tensors,
#     381     grad_tensors_,
#     382     retain_graph,
#     383     create_graph,
#     384     inputs_tuple,
#     385     allow_unreachable=True,
#     386     accumulate_grad=True,
#     387 )
#
# File ~/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/torch/autograd/graph.py:882, in _engine_run_backward(t_outputs, *args, **kwargs)
#     879 torch._C._stash_obj_in_tls("context", contextvars.copy_context())
#     881 try:
# --> 882     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     883         t_outputs, *args, **kwargs
#     884     )  # Calls into the C++ engine to run the backward pass
#     885 finally:
#     886     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Evaluate

# %%
datasets['test']

# %%
# apply the best model loaded after finishing training to the test set
print('Evaluating ...')
test_res = trainer.evaluate(datasets['test'], metric_key_prefix='test')

# %%
test_res

# %% [markdown]
# ### Inference

# %%
classifier = trainer.model.predict

# %%
# for batch inference (see https://huggingface.co/docs/transformers/pipeline_tutorial#batch-inference)
preds = classifier(data_splits['test']['text'].tolist(), as_numpy=True)

# %%
preds_df = pd.DataFrame(preds, columns=[l+'__pred' for l in label_cols], index=data_splits['test'].index)

# %%
tmp = pd.concat([data_splits['test'], preds_df], axis=1)
tmp = tmp.melt(id_vars=['id', 'text'], var_name='col', value_name='value')
tmp['what'] = 'obs'
tmp.loc[tmp['col'].str.endswith('__pred'), 'what'] = 'pred'
tmp['col'] = tmp['col'].str.removesuffix('__pred')
tmp = tmp.pivot(index=['id', 'text', 'col'], columns='what', values='value').reset_index()

# %%
# distribution of how many of the `len(label_cols)` labels were misclassified per text
tmp.assign(misclassified=lambda df: df.eval('obs != pred').astype(int)).groupby('id').misclassified.sum().value_counts().sort_index().to_frame(name='n')

# %%
# Sample examples of misclassifications
miss_examples = tmp.query('obs!=pred').assign(misclassified=lambda df: 'miss').pivot_table(index=['id', 'text'], columns='col', values='misclassified', fill_value='', aggfunc='first').reset_index().sample(20, random_state=SEED)
miss_examples.columns.name = None
miss_examples

# %% [markdown]
# ## Finally

# %% [markdown]
# #### Delete intermediate checkpoints and log files

# %%
# finally: clean up
if checkpoints_dir.exists():
    shutil.rmtree(checkpoints_dir)
if logs_dir.exists():
    shutil.rmtree(logs_dir)

# %% [markdown]
# #### Save the best model (if desired)

# %%
trainer.model._save_pretrained(out_dir)

# %% [markdown]
# ### Free the GPU and remove large objects

# %%
import gc
trainer = trainer.model.to('cpu')
del trainer, datasets
gc.collect()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
