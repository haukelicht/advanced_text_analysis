# %% [markdown]
# # Illustrating the consequences of transformer fine-tuning for text classification
#
# This notebook illustrates how fine-tuning a transformer encoder model for text classifciation affects its embedding behavior.
#
# We take a pre-trained (multilingual) classifier developed by PolTextLab lead by Miklos Sebök: https://capbabel.poltextlab.com/
#
# <br>
# <a target="_blank" href="https://colab.research.google.com/github/haukelicht/advanced_text_analysis/blob/main/notebooks/encoder_finetuning/finetuning_logic_illustrated.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Model access {style="color: orange"}
#
# Note that to use the model, you first need to
#
# 1. sign in to your hugging face acount
# 2. go to https://huggingface.co/poltextlab/xlm-roberta-large-english-parlspeech-cap-v3
# 3. complete the model access form
# 4. wait until you are granted access
#
# If on colab, you also need to add a hugging face token (see https://huggingface.co/settings/tokens)  with "read" permissions to the environment variables in Colab: In the sidebar, click on the key symbol (⚿ ) and add an entry with the name `HF_TOKEN` and the value being your hugging face token.

# %% [markdown]
# ### Setup

# %% [markdown]
# **Note:** If running on Google Colab, make sure to use a GPU runtime (go to Runtime > Change runtime type, select "T4 GPU", and click save)

# %%
# check if on colab
COLAB = True
try:
    import google.colab
except:
    COLAB=False

if COLAB:
    # shallow clone of current state of main branch 
    # !git clone --branch main --single-branch --depth 1 --filter=blob:none https://github.com/haukelicht/advanced_text_analysis.git
    
    # make repo root findable for python
    import sys, os
    sys.path.append(f"{os.getcwd()}/advanced_text_analysis/")
    
    # !pip install -q umap-learn~=0.5.9.post2

# %%
from pathlib import Path

import numpy as np
import pandas as pd

import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification, set_seed

import umap

import matplotlib.pyplot as plt

from typing import List

from tqdm.auto import tqdm

# %%
# check which device is available
device = torch.device('cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu')
device
# Out:
# device(type='mps')

# %%
data_path = "data/labeled/sylvester_parlee_2022"
data_path = ("/content/advanced_text_analysis/" if COLAB else "../../") + data_path
data_path = Path(data_path)

# %%
SOURCE_MODEL_NAME = 'xlm-roberta-large'
FINETUNED_MODEL_NAME = 'poltextlab/xlm-roberta-large-english-parlspeech-cap-v3'

# %% [markdown]
# ## Load the data

# %% [markdown]
# #### Load the codebook

# %%
fp = data_path / "cap_topic_codes.tsv"
if not fp.exists():
    url = "https://cta-text-datasets.s3.eu-central-1.amazonaws.com/labeled/sylvester_parlee_2022/cap_topic_codes.tsv"
    label_map = pd.read_csv(url, sep="\t")
    fp.parent.mkdir(parents=True, exist_ok=True)
    label_map.to_csv(fp, sep="\t", index=False)

label_map = pd.read_csv(fp, sep="\t")
id2label = {row.code: row.topic for row in label_map.itertuples()}
label2id = {v: k for k, v in id2label.items()}

# %%
label_map
# Out:
#     code                                              topic
# 0      1                                     Macroeconomics
# 1      2  Civil Rights, Minority Issues, Immigration and...
# 2      3                                             Health
# 3      4                                        Agriculture
# 4      5                              Labour and Employment
# 5      6                              Education and Culture
# 6      7                                        Environment
# 7      8                                             Energy
# 8      9                                        Immigration
# 9     10                                     Transportation
# 10    12                       Law, Crime and Family Issues
# 11    13                                     Social Welfare
# 12    14  Community Development, Planning and Housing Is...
# 13    15             Banking, Finance and Domestic Commerce
# 14    16                                            Defence
# 15    17      Space, Science, Technology and Communications
# 16    18                                      Foreign Trade
# 17    19              International Affairs and Foreign Aid
# 18    20                              Government Operations
# 19    21  Public Lands, Water Management, Colonial and T...
# 20    99                                 Non-policy content

# %% [markdown]
# #### Load the data

# %%
fp = data_path / "sylvester_parlee_2022-uk_cap_annotations.csv"
if not fp.exists():
    url = "https://cta-text-datasets.s3.eu-central-1.amazonaws.com/labeled/sylvester_parlee_2022/sylvester_parlee_2022-uk_cap_annotations.csv"
    df = pd.read_csv(url, encoding = "ISO-8859-1")
    fp.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(fp, index=False, encoding = "ISO-8859-1")

df = pd.read_csv(fp, encoding = "ISO-8859-1")

df['label'] = df.CAP.map(id2label)
df = df[['text', 'label']]
df = df[~df.text.isna()]

# %%
# show examples of top 10 topics
top10_topics = df['label'].value_counts()[:10].keys().tolist()
examples = df[df.label.isin(top10_topics)]

# sample 64 examples per topic
examples = examples.groupby('label').sample(64, random_state=42)

# show one example per topic (sampled at random)
examples.groupby('label').sample(1, random_state=42)
# Out:
#                                                    text  \
# 1939  I beg to move, That leave be given to bring in...
# 4844  We do need that experience to continue at the ...
# 2904                          We must address that now.
# 2623  Does this represent more than some isolated in...
# 3163  Yes, 135 countries have recognised Palestine a...
# 1490  When the traditional industries were still ope...
# 5189  Notwithstanding what the Minister has said, 40...
# 2636  The principal question for me is whether the s...
# 3903  The review also determined that relative fundi...
# 4800  Every plane flying from Britain to north Ameri...
#
#                                                   label
# 1939             Banking, Finance and Domestic Commerce
# 4844                                            Defence
# 2904                              Government Operations
# 2623                                             Health
# 3163              International Affairs and Foreign Aid
# 1490                              Labour and Employment
# 5189                       Law, Crime and Family Issues
# 2636                                     Macroeconomics
# 3903  Public Lands, Water Management, Colonial and T...
# 4800                                     Transportation

# %% [markdown]
# ## Inspect the transformer embeddings

# %% [markdown]
# Let's first define a function for getting the final contextualized embeddings ("last hidden state") computed by the model:

# %%
# helper function to get the transformer embeddings of a list of texts
def get_last_hidden_state(texts: List[str], tokenizer, model, batch_size: int=32): 
    set_seed(42)
    embeddings = []    
    for i in tqdm(range(0, len(texts), batch_size)):
        # tokenize texts
        batch_inputs = tokenizer(texts[i:i+batch_size], padding='max_length', truncation=True, return_tensors="pt")          
        # get the final hidden layer embeddings
        with torch.no_grad():
            batch_outputs = model(**batch_inputs.to(model.device), output_hidden_states=True)
            # selects all rows (:) and the first column (0) of the last_hidden_state tensor, which corresponds to the representation of the [CLS] that is typically used for classification tasks.
            batch_embeddings = batch_outputs.hidden_states[-1][:, 0].cpu().numpy()
        embeddings.append(batch_embeddings)
            
    embeddings = np.concatenate(embeddings, axis=0)  
    return embeddings

# %% [markdown]
# ### before fine-tuning

# %% [markdown]
# Let's analyze the sentences' contextualized embeddings before fine-tuning the model for the classification task:

# %%
# load the source model and tokenizer
tokenizer = AutoTokenizer.from_pretrained(SOURCE_MODEL_NAME)
model = AutoModelForSequenceClassification.from_pretrained(SOURCE_MODEL_NAME, num_labels=len(label2id), label2id=label2id).to(device)
# Out:
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# get the transformer embeddings
embeddings = get_last_hidden_state(examples.text.tolist(), tokenizer, model)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# Let's visualize how these examples of the different topics cluster in the original model's output embedding space.
# To allow visual inspection, we'll reduce the embedding dimension to 2 dimensions using UMAP:

# %%
# Apply UMAP to reduce embeddings to 2D
reducer = umap.UMAP(n_components=2, random_state=42, n_jobs=1)
embeddings_2d = reducer.fit_transform(embeddings)

# %%
# Plot texts' embeddings in 2D coloring points by values in column label
plt.figure(figsize=(10, 8))
for label in examples['label'].unique():
    indices = examples['label'] == label
    plt.scatter(embeddings_2d[indices, 0], embeddings_2d[indices, 1], label=label, alpha=0.7)
plt.legend()
plt.title('2D UMAP Projection of Text Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()

# %% [markdown]
# There is no clear separating between examples of the different label classes.

# %% [markdown]
# ### The effect of this disorder on classifications

# %% [markdown]
# Let's see how a classifier using these embeddings would classify a single sentence:

# %%
text = examples.text.values[0]
true_label = examples.label.values[0]
print("Text:", repr(text))
print("True Label:", repr(true_label))
# Out:
# Text: 'There is a perception among some that the typical small business owner sits there with an expensive cigar, counting the money, but I assure hon.'
# True Label: 'Banking, Finance and Domestic Commerce'

# %% [markdown]
# Inputting the tokenized version fo the text to the model with the **classification head** outputs logits:

# %%
# get the logits for the first text
text = examples.text.values[0]
inputs = tokenizer(text, return_tensors='pt')
with torch.no_grad():
    outputs = model(**inputs.to(model.device))
logits = outputs.logits.cpu().detach().numpy()[0]

# %% [markdown]
# There are many values as label classes in `logits`:

# %%
logits.shape
# Out:
# (21,)

# %% [markdown]
# Because interpreting logits is hard, let's the logits toprobabilities using the softmax function:

# %%
import torch.nn.functional as F

# Apply softmax to logits and sort by probability
probs = F.softmax(torch.tensor(logits), dim=0).numpy()
# map probs to label class names
probs_dict = dict(zip(label2id.keys(), probs))
# sort by probability
probs_dict = dict(sorted(probs_dict.items(), key=lambda item: item[1]))

# %%
# Apply softmax to logits
probs = F.softmax(torch.tensor(logits), dim=0).numpy()
# sort the softmax logits and corresponding labels
sorted_indices = np.argsort(probs)
probs = probs[sorted_indices]

# %%
# Plot the softmax logits as a bar plot
plt.figure(figsize=(10, 6))
plt.barh(list(probs_dict.keys()), list(probs_dict.values()))
plt.xlabel('Softmax Probability')
plt.ylabel('Topics')
plt.title('Softmax of Logits for Topics')
plt.show()

# %% [markdown]
# We can see that the most likely label class is _wrong_ according to the 'true' label.
#
# But what is more striking is that the classifier seems **really undecided** about what topic it should predict for the sentence!
#
# Well, this is understandable. As we have seen above, the model cannot really separate between texts from different label categories.
#
# This is because it has _not_ been finetuned for this classification task.
#
# So let's look how this looks for a classifier that _has_ been finetuned for this task ☺️

# %% [markdown]
# ## after fine-tuning
#
# Now, let's see what happens if we do the same for the **model that has been _finetuned_** on task-specific labeled data:

# %%
# load the source model and tokenizer
model = AutoModelForSequenceClassification.from_pretrained(FINETUNED_MODEL_NAME).to(device)
# Out:
# config.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]

# %% [markdown]
# #### nice clustering of output embeddings by label class after finetuning ✅

# %% [markdown]
# Below you set, in contrast to the source model, the finetuned model produces contextualized embeddings that are nicely clustering by label class of the inputted texts:

# %%
# get the transformer embeddings
finetuned_embeddings = get_last_hidden_state(examples.text.tolist(), tokenizer, model)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# Apply UMAP to reduce embeddings to 2D
reducer = umap.UMAP(n_components=2, random_state=42, n_jobs=1)
finetuned_embeddings_2d = reducer.fit_transform(finetuned_embeddings)

# %%
# Plot texts' embeddings in 2D coloring points by values in column label
plt.figure(figsize=(10, 8))
for label in examples['label'].unique():
    indices = examples['label'] == label
    plt.scatter(finetuned_embeddings_2d[indices, 0], finetuned_embeddings_2d[indices, 1], label=label, alpha=0.7)
plt.legend()
plt.title('2D UMAP Projection of Fine-Tuned Text Embeddings')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()

# %% [markdown]
# #### High-certainty predicted label class probabilties ✅

# %% [markdown]
# Let's look at the logits predicted by this model

# %%
# get the logits for the first text
# NOTE: we are reusing `text` defined above (`text = examples.text.values[0]`)

inputs = tokenizer(text, return_tensors='pt')
with torch.no_grad():
    outputs = model(**inputs.to(model.device))
logits = outputs.logits.cpu().detach().numpy()[0]

# Apply softmax to logits and sort by probability
probs_finetuned = F.softmax(torch.tensor(logits), dim=0).numpy()
probs_finetuned_dict = dict(zip(label2id.keys(), probs_finetuned))
probs_finetuned_dict = dict(sorted(probs_finetuned_dict.items(), key=lambda item: item[1]))

# Plot the softmax logits as a bar plot
plt.figure(figsize=(10, 6))
plt.barh(list(probs_finetuned_dict.keys()), list(probs_finetuned_dict.values()))
plt.xlabel('Softmax Probability')
plt.xlim(0, 1)
plt.ylabel('Topics')
plt.title('Softmax of Logits for Topics')
plt.show()

# %% [markdown]
# Now this looks much better! The most likely label class aligns with the "true" label with very high probability

# %%
true_label
# Out:
# 'Banking, Finance and Domestic Commerce'

# %% [markdown]
# ## Additional insights

# %% [markdown]
# #### The fine-tuned model gives better cluster assignments

# %% [markdown]
# From the session on sentence embedding clustering and topic modeling, you know that -- given "true" labels -- we can assess the clustering performance of a model using the silhoutte and coherence scores.
#
# These metrics show that the finetuned model's clustering aligns much more with the categorization of the "true" label indicator than the source model:

# %%
from sklearn.metrics import silhouette_score

# Compute Silhouette Score for embeddings
labels = examples['label'].astype('category').cat.codes
silhouette_score_embeddings = silhouette_score(embeddings, labels)
print(f'Silhouette Score for embeddings: {silhouette_score_embeddings}')

# Compute Silhouette Score for finetuned_embeddings
silhouette_score_finetuned_embeddings = silhouette_score(finetuned_embeddings, labels)
print(f'Silhouette Score for finetuned embeddings: {silhouette_score_finetuned_embeddings}')
# Out:
# Silhouette Score for embeddings: -0.09063930809497833
# Silhouette Score for finetuned embeddings: 0.04102429002523422

# %%
from sklearn.metrics import pairwise_distances

def compute_coherence(embeddings, labels):
    label_categories = labels.unique()
    coherence_scores = {}
    
    for label in label_categories:
        label_indices = labels == label
        label_embeddings = embeddings[label_indices]
        
        # Compute pairwise distances within the label category
        distances = pairwise_distances(label_embeddings)
        
        # Compute coherence as the mean of the pairwise distances
        coherence = np.mean(distances)
        coherence_scores[label] = coherence
    
    return coherence_scores

# Compute coherence for embeddings
coherence_embeddings = compute_coherence(embeddings, examples['label'])
coherence_finetuned_embeddings = compute_coherence(finetuned_embeddings, examples['label'])

pd.DataFrame(coherence_embeddings.values(), index=coherence_embeddings.keys(), columns=['embeddings']).join(
    pd.DataFrame(coherence_finetuned_embeddings.values(), index=coherence_finetuned_embeddings.keys(), columns=['finetuned_embeddings'])
)
# Out:
#                                                     embeddings  \
# Banking, Finance and Domestic Commerce                2.599046
# Defence                                               2.561888
# Government Operations                                 2.463580
# Health                                                2.600799
# International Affairs and Foreign Aid                 2.494959
# Labour and Employment                                 2.979536
# Law, Crime and Family Issues                          2.767193
# Macroeconomics                                        2.840460
# Public Lands, Water Management, Colonial and Te...    2.908067
# Transportation                                        2.919642
#
#                                                     finetuned_embeddings
# Banking, Finance and Domestic Commerce                         30.442883
# Defence                                                        25.815054
# Government Operations                                          28.387812
# Health                                                         24.316713
# International Affairs and Foreign Aid                          26.166527
# Labour and Employment                                          30.202049
# Law, Crime and Family Issues                                   27.489395
# Macroeconomics                                                 31.366772
# Public Lands, Water Management, Colonial and Te...             28.136635
# Transportation                                                 28.241816

# %% [markdown]
# #### How much do the embeddings change from the pre-trained checkpoint?

# %% [markdown]
# Finetuning changes the contextualized embeddings of text inputs to make them useful features for separating examples from different label classes.
#
# But how extensive is this change? And how does this vary across examples?
#
# Below we use the cosine similarity of sentences' embeddings pre vs. post finetuning to assess this question:

# %%
# import cosine_similarity from sklearn
from sklearn.metrics.pairwise import cosine_similarity

import seaborn as sns

# Compute the change in embeddings as cosine similarity
embedding_changes = [cosine_similarity(embeddings[i].reshape(1, -1), finetuned_embeddings[i].reshape(1, -1))[0][0] for i in range(len(examples))]

# Add the changes to the examples dataframe
examples['embedding_change'] = embedding_changes

# Plot the distribution of embedding changes in a density plot by label category
plt.figure(figsize=(12, 8))
for label in examples['label'].unique():
    subset = examples[examples['label'] == label]
    sns.kdeplot(subset['embedding_change'], label=label, fill=True, alpha=0.5)

# set the x-axis limits to -1 and 1
plt.xlim(-1, 1)
plt.legend()
plt.title('Distribution of Embedding Changes by Label Category')
plt.xlabel('Embedding Change (Euclidean Distance)')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# While the bulk of sentences' contextualized embeddings change relatively little through finetuning, there are quite some few instances where the change is very intense.
#
# We look at these extreme examples below:

# %%
examples['embedding_change_abs'] = examples.embedding_change.abs()
examples.groupby('label').apply(lambda x: x.sort_values('embedding_change_abs', ascending=False).head(5)).reset_index(drop=True)
# Out:
# /var/folders/_c/cm0nk6y92rz2l6ct3npgw9tr0000gn/T/ipykernel_28427/3447005706.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   examples.groupby('label').apply(lambda x: x.sort_values('embedding_change_abs', ascending=False).head(5)).reset_index(drop=True)
#                                                  text  \
# 0                                               Gone!
# 1   The overwhelming impression is that far too ma...
# 2   I could not agree more with you about the impo...
# 3   They operate in ways that undermine that profe...
# 4   We have heard about a number of issues relatin...
# 5                     Our armed forces are being cut.
# 6   Indeed, it is not just on the high seas that t...
# 7   Friend the Minister for Europe has done in ope...
# 8   Otherwise, I fear that we will have to come ba...
# 9   Otherwise, I fear that we will have to come ba...
# 10                                           I agree.
# 11              Those arrangements are complementary.
# 12                These cuts are really quite modest.
# 13  Does the Prime Minister believe that the Mid S...
# 14  I agree that tens of thousands of people march...
# 15                                             Order.
# 16  In that way, we get the consequential collater...
# 17  That is directly linked to some of the things ...
# 18         I ran the London marathon a few years ago.
# 19  A Marie Stopes clinic has recently opened in N...
# 20                               Old habits die hard.
# 21                   That did not happen by accident.
# 22  The balance of payments facility is a European...
# 23  In fact, will he make representations that we ...
# 24                      Lady's comments on the Kurds.
# 25  Yesterday I attended the opening of the Indust...
# 26  I believe that that is a line we should not cr...
# 27  We have just discovered that Condor Ferries, w...
# 28  We see the potential in the green deal for 100...
# 29  It is great to see that there is a determinati...
# 30  On procedural standards, in a nutshell, those ...
# 31        I thank the Minister for that intervention.
# 32                                  The answer is no.
# 33  That means that we then have to ask search eng...
# 34  Gentleman agree that whatever changes to legal...
# 35                                             Order.
# 36                                            My hon.
# 37               Does that not say it all about them?
# 38                                 What have we done?
# 39                        I am not going to give way.
# 40  We have therefore consulted the Churches in ad...
# 41  I am at one with him on that and have great sy...
# 42  Gentleman and I appreciate his contribution to...
# 43  The briefing note from my researchers says, â...
# 44  Lady for her intervention and for her comments...
# 45                     Now, we are denying them that.
# 46  It is important to mention some major capacity...
# 47  Hardly anybody in Scotland does not know, or k...
# 48  My story about Edinburgh could be told of othe...
# 49  I look forward to April 2014 when we will star...
#
#                                                 label  embedding_change  \
# 0              Banking, Finance and Domestic Commerce          0.712771
# 1              Banking, Finance and Domestic Commerce          0.606925
# 2              Banking, Finance and Domestic Commerce          0.512053
# 3              Banking, Finance and Domestic Commerce          0.414764
# 4              Banking, Finance and Domestic Commerce          0.374507
# 5                                             Defence          0.495186
# 6                                             Defence          0.462131
# 7                                             Defence          0.377306
# 8                                             Defence          0.356390
# 9                                             Defence          0.356390
# 10                              Government Operations          0.665396
# 11                              Government Operations          0.647948
# 12                              Government Operations          0.644815
# 13                              Government Operations          0.590930
# 14                              Government Operations          0.539319
# 15                                             Health          0.769434
# 16                                             Health          0.402646
# 17                                             Health          0.366150
# 18                                             Health         -0.271751
# 19                                             Health          0.261592
# 20              International Affairs and Foreign Aid          0.736135
# 21              International Affairs and Foreign Aid          0.646543
# 22              International Affairs and Foreign Aid          0.402153
# 23              International Affairs and Foreign Aid          0.346370
# 24              International Affairs and Foreign Aid          0.319916
# 25                              Labour and Employment          0.488837
# 26                              Labour and Employment          0.378321
# 27                              Labour and Employment          0.342673
# 28                              Labour and Employment          0.319123
# 29                              Labour and Employment          0.268343
# 30                       Law, Crime and Family Issues          0.459892
# 31                       Law, Crime and Family Issues          0.372826
# 32                       Law, Crime and Family Issues          0.370796
# 33                       Law, Crime and Family Issues          0.333437
# 34                       Law, Crime and Family Issues          0.310066
# 35                                     Macroeconomics          0.769434
# 36                                     Macroeconomics          0.747048
# 37                                     Macroeconomics          0.581575
# 38                                     Macroeconomics          0.468231
# 39                                     Macroeconomics          0.458310
# 40  Public Lands, Water Management, Colonial and T...          0.571758
# 41  Public Lands, Water Management, Colonial and T...          0.419801
# 42  Public Lands, Water Management, Colonial and T...          0.400209
# 43  Public Lands, Water Management, Colonial and T...          0.398927
# 44  Public Lands, Water Management, Colonial and T...          0.361135
# 45                                     Transportation          0.525975
# 46                                     Transportation          0.420595
# 47                                     Transportation          0.300217
# 48                                     Transportation          0.290938
# 49                                     Transportation          0.284251
#
#     embedding_change_abs
# 0               0.712771
# 1               0.606925
# 2               0.512053
# 3               0.414764
# 4               0.374507
# 5               0.495186
# 6               0.462131
# 7               0.377306
# 8               0.356390
# 9               0.356390
# 10              0.665396
# 11              0.647948
# 12              0.644815
# 13              0.590930
# 14              0.539319
# 15              0.769434
# 16              0.402646
# 17              0.366150
# 18              0.271751
# 19              0.261592
# 20              0.736135
# 21              0.646543
# 22              0.402153
# 23              0.346370
# 24              0.319916
# 25              0.488837
# 26              0.378321
# 27              0.342673
# 28              0.319123
# 29              0.268343
# 30              0.459892
# 31              0.372826
# 32              0.370796
# 33              0.333437
# 34              0.310066
# 35              0.769434
# 36              0.747048
# 37              0.581575
# 38              0.468231
# 39              0.458310
# 40              0.571758
# 41              0.419801
# 42              0.400209
# 43              0.398927
# 44              0.361135
# 45              0.525975
# 46              0.420595
# 47              0.300217
# 48              0.290938
# 49              0.284251

# %% [markdown]
# Look at these examples:
#
# - "Gone!" (labeled 'Banking, Finance and Domestic Commerce')
# - "Order." (labeled 'Health')
# - "Old habits die hard." (labeled 'International Affairs and Foreign Aid')
# - "The answer is no." (labeled 'Law, Crime and Family Issues')
# - "I am not going to give way." (labeled 'Macroeconomics')
# - "Now, we are denying them that." (labeled 'Transportation')
#
# Why are these instances assigned their corresponding labels?
# This seems very suspicious!
#
# This prompts us to theorize that the extent of (absolute) change in the contextualized embedding of a sentence might indicate that it has been mislabeled.
# Why?
# Well, the majority of, for example, texts in the 'Health' category likely fits this topical cluster well.
# But to move "Order." to this health cluster, the embedding has to be shifted a lot because it is just not a very health-related term.

# %%
examples.groupby('label').apply(lambda x: x.sort_values('embedding_change_abs', ascending=True).head(5)).reset_index(drop=True)
# Out:
# /var/folders/_c/cm0nk6y92rz2l6ct3npgw9tr0000gn/T/ipykernel_28427/2928638058.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   examples.groupby('label').apply(lambda x: x.sort_values('embedding_change_abs', ascending=True).head(5)).reset_index(drop=True)
#                                                  text  \
# 0   For example, in 2006 RBS approached London and...
# 1   The farmers have suffered a great deal since t...
# 2   The tiresome obsession with grudge is wearing ...
# 3   That is unprecedented in our financial system ...
# 4   Member for Bridgwater (Mr. Liddell-Grainger) a...
# 5   Friend the Member for New Forest East (Dr Lewi...
# 6   In the remaining time available to me, however...
# 7   Clearly, the withdrawal of one of the potentia...
# 8                                            The hon.
# 9   I beg to move, That this House: Deplores the u...
# 10  It is a pleasure to sum up the motion proposed...
# 11  The Government's answer is simply not good eno...
# 12  It owns about 19,000 hectares of land, valued ...
# 13  Exactly a month later, on 28 July, Austria-Hun...
# 14  I note the sudden appearance next Thursday of ...
# 15  Some of the projects being carried out by this...
# 16  We need to give them the ability to discuss wh...
# 17  There is concern about the unfairness of a sys...
# 18  Will the Secretary of State give me an assuran...
# 19  Friend the Member for North Norfolk, who takes...
# 20  As recently as 2008, we saw what President Put...
# 21  How far are the United Kingdom and the interna...
# 22  In the remaining time available to me, however...
# 23  Will the Foreign Secretary make it clear to th...
# 24  The Prime Minister also mentioned the Loya Jirga.
# 25  What assessment he has made of recent trends i...
# 26  Will he ensure that no legislation is introduc...
# 27  Women hold about two thirds of jobs in the pub...
# 28  The principal question for me is whether the s...
# 29  Let us be clear: if Labour had won the electio...
# 30                          However, it may help hon.
# 31  The large case loads of probation officers is ...
# 32  Access to the probation services based in Neat...
# 33  When probation officers dared to criticise the...
# 34  He will undertake that important work with the...
# 35  Today's measures, combined with those from the...
# 36  We plan to lead the debate as we enter the nex...
# 37  Gentleman highlighted, which is the move from ...
# 38  We should be talking about trade, widening the...
# 39  We have had to deal with his economic legacy a...
# 40  When I speak to benefits centres in Northern I...
# 41  Gentleman accept that if a similar rationale w...
# 42  I want to stress the positive benefits that a ...
# 43  Gentleman's central point is correct: by all t...
# 44  It is always dangerous to wander into territor...
# 45  The evidence is that this does not appear to b...
# 46  Where does he think the majority of his consti...
# 47  Nevertheless, he is right and he will have not...
# 48  Dublin and London can be linked via north Wale...
# 49                 That may be the source of the hon.
#
#                                                 label  embedding_change  \
# 0              Banking, Finance and Domestic Commerce          0.013486
# 1              Banking, Finance and Domestic Commerce         -0.017321
# 2              Banking, Finance and Domestic Commerce          0.019113
# 3              Banking, Finance and Domestic Commerce         -0.019911
# 4              Banking, Finance and Domestic Commerce          0.020234
# 5                                             Defence         -0.006242
# 6                                             Defence          0.010182
# 7                                             Defence          0.010834
# 8                                             Defence          0.012226
# 9                                             Defence          0.016125
# 10                              Government Operations         -0.005258
# 11                              Government Operations         -0.012164
# 12                              Government Operations          0.014381
# 13                              Government Operations          0.016942
# 14                              Government Operations         -0.020956
# 15                                             Health         -0.000142
# 16                                             Health          0.005395
# 17                                             Health          0.006554
# 18                                             Health          0.007534
# 19                                             Health          0.008225
# 20              International Affairs and Foreign Aid          0.001113
# 21              International Affairs and Foreign Aid         -0.008086
# 22              International Affairs and Foreign Aid          0.010182
# 23              International Affairs and Foreign Aid          0.033932
# 24              International Affairs and Foreign Aid         -0.035359
# 25                              Labour and Employment         -0.000607
# 26                              Labour and Employment         -0.004293
# 27                              Labour and Employment         -0.004713
# 28                              Labour and Employment         -0.006888
# 29                              Labour and Employment         -0.008093
# 30                       Law, Crime and Family Issues         -0.008103
# 31                       Law, Crime and Family Issues          0.019293
# 32                       Law, Crime and Family Issues          0.024481
# 33                       Law, Crime and Family Issues          0.030025
# 34                       Law, Crime and Family Issues          0.032836
# 35                                     Macroeconomics         -0.000693
# 36                                     Macroeconomics          0.003633
# 37                                     Macroeconomics          0.004169
# 38                                     Macroeconomics          0.004640
# 39                                     Macroeconomics         -0.006407
# 40  Public Lands, Water Management, Colonial and T...         -0.000598
# 41  Public Lands, Water Management, Colonial and T...         -0.001436
# 42  Public Lands, Water Management, Colonial and T...          0.003419
# 43  Public Lands, Water Management, Colonial and T...          0.003457
# 44  Public Lands, Water Management, Colonial and T...         -0.005171
# 45                                     Transportation         -0.001902
# 46                                     Transportation          0.003659
# 47                                     Transportation         -0.009277
# 48                                     Transportation          0.018204
# 49                                     Transportation         -0.022789
#
#     embedding_change_abs
# 0               0.013486
# 1               0.017321
# 2               0.019113
# 3               0.019911
# 4               0.020234
# 5               0.006242
# 6               0.010182
# 7               0.010834
# 8               0.012226
# 9               0.016125
# 10              0.005258
# 11              0.012164
# 12              0.014381
# 13              0.016942
# 14              0.020956
# 15              0.000142
# 16              0.005395
# 17              0.006554
# 18              0.007534
# 19              0.008225
# 20              0.001113
# 21              0.008086
# 22              0.010182
# 23              0.033932
# 24              0.035359
# 25              0.000607
# 26              0.004293
# 27              0.004713
# 28              0.006888
# 29              0.008093
# 30              0.008103
# 31              0.019293
# 32              0.024481
# 33              0.030025
# 34              0.032836
# 35              0.000693
# 36              0.003633
# 37              0.004169
# 38              0.004640
# 39              0.006407
# 40              0.000598
# 41              0.001436
# 42              0.003419
# 43              0.003457
# 44              0.005171
# 45              0.001902
# 46              0.003659
# 47              0.009277
# 48              0.018204
# 49              0.022789
