# %% [markdown]
# # Fine-tune multi-label sequence classifier
#
# *author*: **Hauke Licht** (hauke.licht@uibk.ac.at)
#
# <br>
#
# In this notebook, we fine-tune a transformer encoder for multilabel
# classification with replication data from
#
# > Erlich A, Dantas SG, Bagozzi BE, Berliner D, Palmer-Rub. Multi-Label Prediction for Political Text-as-Data. *Political Analysis*. 2022; 30(4):463-480. DOI: [10.1017/pan.2021.15](https://doi.org/10.1017/pan.2021.15)
#
#
# Unlike SetFit, this notebook updates the encoder and a multilabel classification
# head with the standard Transformers `Trainer`.
#
#
# <a target="_blank" href="https://colab.research.google.com/github/haukelicht/advanced_text_analysis/blob/main/notebooks/encoder_finetuning/finetune_sequence_classifier_multilabel.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# **Note:** If running on Google Colab, make sure to use a GPU runtime (go to Runtime > Change runtime type, select "T4 GPU", and click save). See [this guide](https://github.com/haukelicht/advanced_text_analysis/blob/main/setup/setup_colab_runtime.md).

# %% [markdown]
# ## Background
#
# **Multilabel classification** means assigning each text item into none, one, or more label classes.
#
# <center>
#
# ![](../.assets/task_types-multilabel_classification.svg)
#
# </center>
#
# defining characteristics:
#
# - document-level classification: assign whole documents (e.g., sentences) categories
# - _multi_-label classification: assign each document to _none, one, or more_ categories
#
# ### multi-label classification implementation
#
# #### supervised learning (finetuning)
#
# given
#
# - pre-defined set of label classes C
# - n training examples ($x_i$, $\mathbf{y}_i$) where
# 	- $x_i$ is example i's text (representation) and
# 	- $\mathbf{y}_i$ is example i's _list of_ "ground truth" labels
# - a (pre-trained) model that
# 	- intakes text representations ($x_i$)
# 	- outputs _vector of_ predicted probabilities $\mathbf{\hat{y}}_i$
# - loss function: label-class specific binary cross entropy
#
# #### prompting (in-context learning)
#
# two approaches
#
# - collect binary (yes/no) classifications for each label class
# - prompt model to choose any label classes that apply
#
# ### methods papers and research applications
#
# - Erhard L, Hanke S, Remer U, Falenska A, Heiberger RH. PopBERT. Detecting Populism and Its Host Ideologies in the German Bundestag. *Political Analysis*. 2025;33(1):1-17. doi:[10.1017/pan12](https://doi.org/10.1017/pan.2024.12)
# - Erlich A, Dantas SG, Bagozzi BE, Berliner D, Palmer-Rub. Multi-Label Prediction for Political Text-as-Data. *Political Analysis*. 2022; 30(4):463-480. doi:[10.1017/pan.2021.15](https://doi.org/10.1017/pan.2021.15)
# - Kroon AC, van der Meer T, Vliegenthart R. Assessing Performance of Dictionaries, Supervised Machine Learning, and Embeddings in Topic and Frame Classification. *Computational Communication Research*. 2022; 4(2): 528 - 570. doi:[10.5117/CCR2022.2.006.KROO](https://doi.org/10.5117/CCR2022.2.006.KROO)
# <!-- - Omar A, Mahmoud TM, Abd-El-Hafeez T, Mahfouz A. Multi-label Arabic text classification in Online Social Networks. *Information Systems*. 2021; 100. doi:[10.1016/j.is.2021.101785](https://doi.org/10.1016/j.is.2021.101785) -->

# %% [markdown]
# ## Setup
#
# #### Colab (if necessary)

# %%
# check if on Colab
COLAB = True
try:
  from google import colab
except:
  COLAB = False

if COLAB:
    # shallow clone of current state of main branch 
    # %rm -rf advanced_text_analysis
    # !git clone --branch main --single-branch --depth 1 --filter=blob:none https://github.com/haukelicht/advanced_text_analysis.git

# %%
# set the PYTHONPATH so modules in `src/` can be found
from pathlib import Path
import sys

if COLAB:
    import sys
    sys.path.append("/content/advanced_text_analysis/")
else:
    base_path = Path('../..')
    sys.path.append(str(base_path.resolve()))

# %% [markdown]
# #### Load required libraries

# %%
from pathlib import Path
import shutil

import numpy as np
import pandas as pd
from datasets import Dataset, DatasetDict

from src.utils.io import read_tabular
from src.finetuning import split_data

import torch
from transformers import (
    AutoTokenizer,
    AutoConfig,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
    DataCollatorWithPadding,
    EarlyStoppingCallback,
    set_seed,
)

from src.metrics import (
    parse_sequence_classifier_prediction_output_multilabel,
    compute_sequence_classification_metrics_multilabel
)

# %%
def compute_metrics(pred):
    y_true, y_pred = parse_sequence_classifier_prediction_output_multilabel(pred)
    return compute_sequence_classification_metrics_multilabel(y_true, y_pred)

# %%
# check which device is available
device = torch.device('cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu')
device
# Out:
# device(type='mps')

# %%
SEED = 42
set_seed(SEED)

# %%
MODEL_NAME = "answerdotai/ModernBERT-base"

# %%
base_path = Path("/content/advanced_text_analysis/" if COLAB else "../../")
data_path = base_path / "data" / "labeled" / "erlich_multilabel_2023"
data_file = "erlich_multilabel_2023-ati_reqeuests.tsv"

# %% [markdown]
# ## Load and prepare the data

# %%
fp = data_path / data_file
if not fp.exists():
    url = f"https://cta-text-datasets.s3.eu-central-1.amazonaws.com/labeled/{data_path.name}/{data_file}"
    df = pd.read_csv(url, sep="\t")
    fp.parent.mkdir(parents=True, exist_ok=True)
    df.to_csv(fp, sep="\t", index=False)

# %%
df = read_tabular(fp)

# %%
del df['text']
df.rename(columns={'text_en': 'text'}, inplace=True)

# %%
data_splits = split_data(df, dev_size=0.10, test_size=0.15, seed=SEED, return_dict=True)

# %%
datasets = DatasetDict({
    s: Dataset.from_pandas(df, preserve_index=False)
    for s, df in data_splits.items()
})

# %%
metadata_cols = {"id", "text"}
label_cols = [
    col for col in datasets.column_names["train"]
    if col not in metadata_cols
]
if not label_cols:
    raise ValueError("No multilabel indicator columns found.")
label_cols
# Out:
# ['activities',
#  'budget',
#  'evaluation',
#  'external_contracts',
#  'inst_struc',
#  'regulatory']

# %%
# Check that every label is represented in every split before training.
label_support = pd.DataFrame({
    split: [sum(datasets[split][col]) for col in label_cols]
    for split in datasets
}, index=label_cols)
if label_support.eq(0).any().any():
    missing = label_support.index[label_support.eq(0).any(axis=1)].tolist()
    raise ValueError(f"Labels absent from at least one split: {missing}")
label_support
# Out:
#                     train  dev  test
# activities           1494  194   297
# budget                550   79   102
# evaluation            726   95   143
# external_contracts    527   91   107
# inst_struc            959  124   205
# regulatory            352   38    60

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, use_fast=True)

# %%
def preprocess_function(examples):
    return tokenizer(examples["text"], max_length=tokenizer.max_len_single_sentence, padding=False, truncation=True)

def format_labels(example):
    example['labels'] = [float(example[col]) for col in label_cols]
    return example

# %%
datasets = datasets.map(format_labels)
datasets = datasets.map(preprocess_function)
# Out:
# Map:   0%|          | 0/3587 [00:00<?, ? examples/s]
# Map:   0%|          | 0/478 [00:00<?, ? examples/s]
# Map:   0%|          | 0/717 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3587 [00:00<?, ? examples/s]
# Map:   0%|          | 0/478 [00:00<?, ? examples/s]
# Map:   0%|          | 0/717 [00:00<?, ? examples/s]

# %%
keep_cols = ['input_ids', 'attention_mask', 'labels']
rm_cols = [col for col in datasets['train'].column_names if col not in keep_cols]
datasets = datasets.remove_columns(rm_cols)

# %% [markdown]
# ## Prepare the model fine-tuning

# %%
# NOTE: the `model_init` function is used by the Trainer to initialize the model
#   and is called each time before training starts.
#  So we define it here to load the model from the Huggingface model hub
#   and set the number of labels to the number of unique labels in the dataset
#   and the label2id and id2label mappings
def model_init():
    config = AutoConfig.from_pretrained(MODEL_NAME, trust_remote_code=True)
    config.num_labels = len(label_cols)
    config.label2id = {l: i for i, l in enumerate(label_cols)}
    config.id2label = {i: l for i, l in enumerate(label_cols)}
    config.problem_type = "multi_label_classification"
    return AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, config=config, trust_remote_code=True)

# %% [markdown]
# ### Define the training arguments

# %%
model_path = base_path / "models" / "erlich_multilabel"

# %%
out_dir = model_path
checkpoints_dir = out_dir / 'checkpoints'

training_args = TrainingArguments(
    
    # hyperparameters
    num_train_epochs=2,
    learning_rate=4e-5,
    per_device_train_batch_size=16,
    gradient_accumulation_steps=2,
    per_device_eval_batch_size=32,
    weight_decay=0.3,
    optim='adamw_torch',
    
    # when to evaluate
    eval_strategy='epoch',
    # how to select "best" model
    do_eval=bool('dev' in datasets),
    metric_for_best_model='f1_macro',
    load_best_model_at_end=True,
    # when to save
    save_strategy='epoch',
    save_total_limit=2 if 'dev' in datasets else None, # don't save all model checkpoints
    # where to store results
    output_dir=checkpoints_dir,
    
    # logging
    logging_strategy='epoch',
    
    # reproducibility
    seed=SEED,
    data_seed=SEED,
    full_determinism=True
)


# build callbacks
callbacks = []
if 'dev' in datasets:
    callbacks.append(EarlyStoppingCallback(early_stopping_patience=3, early_stopping_threshold=0.03))

# %% [markdown]
# ### Create the trainer

# %%
trainer = Trainer(
    model_init=model_init,
    args=training_args,
    train_dataset=datasets['train'],
    eval_dataset=datasets['dev'] if 'dev' in datasets else None,
    processing_class=tokenizer,
    data_collator=DataCollatorWithPadding(tokenizer=tokenizer),
    compute_metrics=compute_metrics,
    callbacks=callbacks
)
# Out:
# Loading weights:   0%|          | 0/136 [00:00<?, ?it/s]
# [transformers] ModernBertForSequenceClassification LOAD REPORT from: answerdotai/ModernBERT-base
# Key               | Status     |
# ------------------+------------+-
# decoder.bias      | UNEXPECTED |
# classifier.weight | MISSING    |
# classifier.bias   | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %% [markdown]
# ## Train

# %%
print('Training ...')
train_hist = trainer.train()
# Out:
# Training ...
# Loading weights:   0%|          | 0/136 [00:00<?, ?it/s]
# [transformers] ModernBertForSequenceClassification LOAD REPORT from: answerdotai/ModernBERT-base
# Key               | Status     |
# ------------------+------------+-
# decoder.bias      | UNEXPECTED |
# classifier.weight | MISSING    |
# classifier.bias   | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': None, 'bos_token_id': None}.
#     <div>
#
#       <progress value='226' max='226' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [226/226 11:54, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Hamming Loss</th>
#       <th>Subset Accuracy</th>
#       <th>F1 Macro</th>
#       <th>F1 Micro</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#       <th>Steps Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.871332</td>
#       <td>0.376586</td>
#       <td>0.167713</td>
#       <td>0.355649</td>
#       <td>0.470938</td>
#       <td>0.557498</td>
#       <td>17.011200</td>
#       <td>28.099000</td>
#       <td>0.882000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.622214</td>
#       <td>0.347451</td>
#       <td>0.150976</td>
#       <td>0.384937</td>
#       <td>0.551589</td>
#       <td>0.592662</td>
#       <td>14.775300</td>
#       <td>32.351000</td>
#       <td>1.015000</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/hlicht/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Evaluate

# %%
# apply the best model loaded after finishing training to the test set
print('Evaluating ...')
test_res = trainer.evaluate(datasets['test'], metric_key_prefix='test')
# Out:
# Evaluating ...
# /Users/hlicht/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='23' max='23' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [23/23 00:20]
#     </div>
# [transformers] early stopping required metric_for_best_model, but did not find eval_f1_macro so early stopping is disabled
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Epoch</th>
#       <th>Hamming Loss</th>
#       <th>Subset Accuracy</th>
#       <th>F1 Macro</th>
#       <th>F1 Micro</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#       <th>Steps Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.622214</td>
#       <td>0.361206</td>
#       <td>2</td>
#       <td>0.161785</td>
#       <td>0.365411</td>
#       <td>0.516725</td>
#       <td>0.548052</td>
#       <td>21.984700</td>
#       <td>32.614000</td>
#       <td>1.046000</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
test_res
# Out:
# {'test_loss': 0.3612055778503418,
#  'test_hamming_loss': 0.16178521617852162,
#  'test_subset_accuracy': 0.36541143654114366,
#  'test_f1_macro': 0.5167250700418161,
#  'test_f1_micro': 0.548051948051948,
#  'test_runtime': 21.9847,
#  'test_samples_per_second': 32.614,
#  'test_steps_per_second': 1.046}

# %%
preds = trainer.predict(datasets['test'])
# Out:
# /Users/hlicht/miniforge3/envs/advanced_text_analysis/lib/python3.11/site-packages/torch/utils/data/dataloader.py:752: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)

# %%
# compute sigmoid and threshold
probs = 1 / (1 + np.exp(-preds.predictions))  # Sigmoid
pred_binary = (probs > 0.5).astype(int)

# %%
# create a confusion matrix
from sklearn.metrics import multilabel_confusion_matrix
cm = multilabel_confusion_matrix(preds.label_ids, pred_binary)

# reshape to 2D
cm_wide = cm.reshape(-1, 4)

# create a DataFrame
cm_df = pd.DataFrame(cm_wide, columns=['TN', 'FP', 'FN', 'TP'])
cm_df.index = label_cols
cm_df = cm_df[['TP', 'TN', 'FP', 'FN']] 
cm_df /= len(datasets['test'])
cm_df.round(3)
# Out:
#                        TP     TN     FP     FN
# activities          0.202  0.462  0.124  0.212
# budget              0.081  0.827  0.031  0.061
# evaluation          0.071  0.763  0.038  0.128
# external_contracts  0.077  0.812  0.039  0.073
# inst_struc          0.142  0.679  0.035  0.144
# regulatory          0.015  0.898  0.018  0.068

# %%
# which label classes get most frquently confused?
cm_df['FP_rate'] = cm_df['FP'] / (cm_df['FP'] + cm_df['TN'])
cm_df['FN_rate'] = cm_df['FN'] / (cm_df['FN'] + cm_df['TP'])
cm_df['FP_rate'].sort_values(ascending=False).head(10)
# Out:
# activities            0.211905
# inst_struc            0.048828
# evaluation            0.047038
# external_contracts    0.045902
# budget                0.035772
# regulatory            0.019787
# Name: FP_rate, dtype: float64

# %%
# which label classes get most frquently confused with each other?
conf = np.zeros((len(label_cols), len(label_cols)))
for y_true, y_pred in zip(preds.label_ids, pred_binary):
    # get label classes with false positive classification
    fp = np.where((y_true == 0) & (y_pred == 1))[0]
    # get label classes with false negative classification
    fn = np.where((y_true == 1) & (y_pred == 0))[0]
    # update confusion matrix
    for i in fp:
        for j in fn:
            conf[i, j] += 1
conf_df = pd.DataFrame(conf, index=label_cols, columns=label_cols)
conf_df = conf_df.astype(int)

# pivot longer
conf_df = conf_df.stack().reset_index()
conf_df.columns = ['label_true', 'label_pred', 'count']
# conf_df = conf_df[conf_df['count'] > 0]
# conf_df = conf_df.sort_values(by='count', ascending=False)
conf_df.pivot(index='label_true', columns='label_pred', values='count').fillna(0).astype(int)
# Out:
# label_pred          activities  budget  evaluation  external_contracts  \
# label_true
# activities                   0       5          18                  12
# budget                      10       0           5                   0
# evaluation                   7       1           0                   3
# external_contracts          19       3           3                   0
# inst_struc                  13       1           5                   3
# regulatory                   6       0           0                   2
#
# label_pred          inst_struc  regulatory
# label_true
# activities                  24          15
# budget                       2           0
# evaluation                   4           1
# external_contracts           4           2
# inst_struc                   0           4
# regulatory                   1           0

# %% [markdown]
# ### Inference

# %%
from datasets import Dataset

from transformers import pipeline
from transformers.pipelines.pt_utils import KeyDataset

from tqdm import tqdm

# %% [markdown]
# We'll use the Transformers text-classification pipeline to obtain one sigmoid score
# per label for each text. Applying a threshold converts these scores into a set of
# predicted labels. The conventional threshold of 0.5 is a starting point; in a
# research application, thresholds can be selected per label using the development
# set and then evaluated once on the test set.

# %%
classifier = pipeline(
    "text-classification", 
    model=trainer.model,
    tokenizer=tokenizer,
    return_all_scores=True,
    function_to_apply="sigmoid",
    top_k=None
)

# %%
# for batch inference (see https://huggingface.co/docs/transformers/pipeline_tutorial#batch-inference)
kd = KeyDataset(Dataset.from_pandas(data_splits['test'][['text']]), 'text')

# %%
# apply the extractor to the dataset
preds = [p for p in tqdm(classifier(kd, batch_size=32), total=len(kd))]
# Out:
# 100%|██████████| 717/717 [00:22<00:00, 31.74it/s]

# %%
preds_df = pd.DataFrame([{p['label']+'__pred': int(p['score'] >= 0.5) for p in pred} for pred in preds])
preds_df.index = data_splits['test'].index

# %%
tmp = pd.concat([data_splits['test'], preds_df], axis=1)
tmp = tmp.melt(id_vars=['id', 'text'], var_name='col', value_name='value')
tmp['what'] = 'obs'
tmp.loc[tmp['col'].str.endswith('__pred'), 'what'] = 'pred'
tmp['col'] = tmp['col'].str.removesuffix('__pred')
tmp = tmp.pivot(index=['id', 'text', 'col'], columns='what', values='value').reset_index()

# %%
# distribution of how many of the `len(label_cols)` labels were misclassified per text
tmp.assign(misclassified=lambda df: df.eval('obs != pred').astype(int)).groupby('id').misclassified.sum().value_counts().sort_index().to_frame(name='n')
# Out:
#                  n
# misclassified
# 0              262
# 1              250
# 2              170
# 3               34
# 4                1

# %%
# Sample examples of misclassifications
miss_pool = tmp.query('obs!=pred').assign(misclassified=lambda df: 'miss').pivot_table(index=['id', 'text'], columns='col', values='misclassified', fill_value='', aggfunc='first').reset_index()
miss_examples = miss_pool.sample(min(20, len(miss_pool)), random_state=SEED)
miss_examples.columns.name = None
miss_examples
# Out:
#        id                                               text activities  \
# 302  3247                  APPLYING REQUEST FOR INFORMATION.
# 39    434  Manual of Procedures for the Presidency of the...       miss
# 393  4345  The current and express office or document aut...       miss
# 411  4523  copies of the documents containing the registr...       miss
# 155  1522  We request the list of social projects for 200...       miss
# 255  2718  I request resume from the members of the Subco...
# 244  2609  Higher education database where you can track ...       miss
# 101  1001  Good day I thank you in advance for taking a f...
# 401  4442  Please provide information on the concept: Com...       miss
# 30    302  What research has been done on the effects low...
# 72    736  I would like to know the salary tabulator of t...
# 204  2164  Please inform me carefully of the medical pres...       miss
# 140  1361  DOCUMENTATION ON THE ORIGIN OF DESTINATION AND...       miss
# 353  3905  To report on possible administrative proceedin...       miss
# 317  3490  What are the number of vehicles purchased in 2...
# 55    596  What are the members of the Internal Committee...       miss
# 168  1641  I would like to know what legal status the Dis...
# 229  2401  In accordance with the Transparency and Access...       miss
# 291  3151  Constitutions of other countries compel the re...
# 82    782  I refer to the SMALL AND MEDIUM-BATCHED COPY’S...
#
#     budget evaluation external_contracts inst_struc regulatory
# 302                                            miss
# 39
# 393
# 411
# 155              miss
# 255                                            miss
# 244              miss
# 101              miss
# 401                                            miss
# 30               miss
# 72    miss
# 204
# 140   miss
# 353              miss
# 317   miss
# 55
# 168                                                       miss
# 229                                                       miss
# 291              miss
# 82                                  miss       miss

# %% [markdown]
# ## Finally
#
# #### Delete intermediate checkpoints and log files

# %%
import os
# finally: clean up
if checkpoints_dir.exists():
    shutil.rmtree(checkpoints_dir)

# %% [markdown]
# #### Save the best model (if desired)

# %%
trainer.save_model(out_dir)
tokenizer.save_pretrained(out_dir);
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Clean up

# %%
# free the GPU and remove large objects
import gc
trainer.model.to('cpu')
del trainer, tokenizer, datasets
gc.collect()
# Out:
# 7801

# %%
# delete the saved model (to save disk space)
if out_dir.exists():
    shutil.rmtree(out_dir)
